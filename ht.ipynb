# %%
import pandas as pd

# %%
df=pd.read_csv("heart.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
 cleaned_df = df.drop_duplicates()

# %%
cleaned_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
cleaned_df1=cleaned_df.dropna()  # Remove rows with missing/null values
cleaned_df1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
 merged_df = pd.merge( cleaned_df,  cleaned_df1)

# %%
merged_df.tail(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 297   68    0   2       120   211    0        0      115      0      1.5
# 298   44    0   2       108   141    0        1      175      0      0.6
# 299   52    1   0       128   255    0        1      161      1      0.0
# 300   59    1   3       160   273    0        0      125      0      0.0
# 301   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 297      1   0     2       1
# 298      1   0     2       1
# 299      2   1     3       0
# 300      2   0     2       0
# 301      1   1     3       0

# %%
transformed_df = merged_df.apply(lambda x: x**2)

# %%
transformed_df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
errorless=transformed_df

# %%
X= errorless.drop('target', axis=1) #dropping values
Y=errorless["target"]

# %%
pd.DataFrame(X)
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    2704    1   0     15625  44944    0        1    28224      0     1.00
# 1    2809    1   0     19600  41209    1        0    24025      1     9.61
# 2    4900    1   0     21025  30276    0        1    15625      1     6.76
# 3    3721    1   0     21904  41209    0        1    25921      0     0.00
# 4    3844    0   0     19044  86436    1        1    11236      0     3.61
# ..    ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 297  4624    0   4     14400  44521    0        0    13225      0     2.25
# 298  1936    0   4     11664  19881    0        1    30625      0     0.36
# 299  2704    1   0     16384  65025    0        1    25921      1     0.00
# 300  3481    1   9     25600  74529    0        0    15625      0     0.00
# 301  2916    1   0     14400  35344    0        1    12769      0     1.96
#
#      slope  ca  thal
# 0        4   4     9
# 1        0   0     9
# ...

# %%
pd.DataFrame(Y)
# Out:
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 297       1
# 298       1
# 299       0
# 300       0
# 301       0
#
# [302 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train 
# Initialize the logistic regression model
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 132  2304    1   0     15376  75076    0        0    27556      0     0.25
# 202  3364    1   0     16384  67081    0        0    16900      1     9.00
# 196  2025    0   1     16900  54756    0        0    30625      0     0.36
# 75   1936    1   1     14400  48400    0        1    28900      0     0.00
# 176  3844    0   0     22500  59536    0        1    23716      1     1.96
# ..    ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 188  4489    1   0     14400  56169    0        1     5041      0     1.00
# 71   3969    1   0     19600  34969    0        0    20736      1    16.00
# 106  3600    0   9     22500  57600    0        1    29241      0     0.81
# 270  4489    0   4     23104  76729    0        1    29584      0     0.00
# 102  1764    1   1     14400  87025    0        1    26244      0     0.00
#
#      slope  ca  thal
# 132      1   0     9
# 202      1   4     9
# ...

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7868852459016393
